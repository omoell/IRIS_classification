# %% [markdown]
# # Import Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.metrics import confusion_matrix
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.linear_model import LinearRegression
from sklearn.utils.multiclass import unique_labels

# %% [markdown]
# # Data import and summary analysis

# %%
iris = pd.read_csv("Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Drop column "Id" as it is redundant with Index.

# %%
iris.drop("Id", axis=1, inplace=True)

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # Visual Data Analysis

# %% [markdown]
# Create correlation matrix for features to understand dependency between features

# %%
iris.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %% [markdown]
# Plot correlation matrix with Matplotlib

# %%
sns.set()
plt.pcolor(iris.corr(), cmap="RdBu", vmin=-1, vmax=1)
plt.colorbar()
plt.show()

# %% [markdown]
# Plot correlation matrix with seaborn - Pay attention to line of codes and display of labels and figures out of the box

# %%
sns.heatmap(iris.corr(), vmin=-1, vmax=1, cmap="RdBu", annot=True)

# %% [markdown]
# As a test - calculate statistical indicators for two randomly selected features

# %%
Pearson_coef, p_value = stats.pearsonr(iris["PetalLengthCm"],iris["SepalLengthCm"])
print(f"Correlation: {Pearson_coef}")
print(f"P-Value: {p_value}")
# Out:
# Correlation: 0.8717541573048713
# P-Value: 1.0384540627941062e-47

# %% [markdown]
# Grid of scatter plot to visualize potential correlation of feature vs. feature

# %%
sns.pairplot(iris, kind="scatter", hue="Species")

# %% [markdown]
# Just another test for one plot in larger size

# %%
sns.set()
sns.relplot(x="PetalLengthCm", y="PetalWidthCm", hue="Species", data=iris)
plt.xlim(0,)
# Out:
# (0, 7.19620440953242)

# %% [markdown]
# # Modeling and Evaluation

# %% [markdown]
# Split prediction target (Y) and feature data (X)

# %%
y = iris["Species"]
X = iris.drop("Species", axis=1)

# %% [markdown]
# ## First Model Evaluation

# %% [markdown]
# Split Train and Test Data with fixed seed (9) to ensure same random data is picked every time. If data would be randomized each time, changes to the data or model could not be evaluated, as results change due to different training and test data.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=9, test_size=.25)

# %% [markdown]
# Initialize models and get prediction score per model.

# %%
def model_evaluation(model, name, X_train_eval, y_train_eval, X_test_eval, y_test_eval):
    model.fit(X_train_eval, y_train_eval)
    y_predict_eval = model.predict(X_test_eval)
    wrong_absolute = len(y_test_eval) - sum(y_test_eval == y_predict_eval)
    print(f"{name}: {model.score(X_test_eval, y_test_eval)} (Wrong: {wrong_absolute})")

mnb = MultinomialNB()
gnb = GaussianNB()
knn = KNeighborsClassifier(n_neighbors=3)

models = [mnb, gnb, knn]

for model in models:
    model_evaluation(model, model.__class__.__name__, X_train, y_train, X_test, y_test)
# Out:
# MultinomialNB: 0.868421052631579 (Wrong: 5)
# GaussianNB: 1.0 (Wrong: 0)
# KNeighborsClassifier: 1.0 (Wrong: 0)

# %% [markdown]
# GaussianNB and KNeighborsClassifier perform with 100% prediction quality.
# MultinomialNB performs better with categorical features. So it was expected that Gaussian Naive Bayes performes better, as the features are metrics.
#
# Remark:
# Changing parameter "n_neighbors" to 2, will reduce prediction quality of the model below 100%.

# %% [markdown]
# ## Due to the very small data size, check if the random train and test data variation has an impact on the prediction results (should not be relevant for large data sizes)

# %%
def sampling(models, X_samp, y_samp, randoms):
    results_dict = {}
    for model in models:
        results = []
        for random in range(0, randoms):
            X_train_samp, X_test_samp, y_train_samp, y_test_samp = train_test_split(X_samp, y_samp, random_state=random, test_size=.25)
            model.fit(X_train_samp, y_train_samp)
            results.append(model.score(X_test_samp, y_test_samp))
        results_dict[model.__class__.__name__] = results
    return results_dict

results = sampling(models, X, y, 10)
results = pd.DataFrame(results)
sns.lineplot(data=results)

# %% [markdown]
# ## For curiousity: Test prediction quality of Multinomial Naive Bayes model by reducing the number of features to two.

# %%
columns_count = len(X_train.columns)
for i in range(0, (columns_count-1)):
    for j in range((i+1), columns_count):
        column1 = X_train.columns[i]
        column2 = X_train.columns[j]
        model_evaluation(
            mnb,
            str(column1.ljust(16) + column2.ljust(16)),
            X_train[[column1, column2]],
            y_train,
            X_test[[column1, column2]],
            y_test
        )
# Out:
# SepalLengthCm   SepalWidthCm    : 0.42105263157894735 (Wrong: 22)
# SepalLengthCm   PetalLengthCm   : 0.7105263157894737 (Wrong: 11)
# SepalLengthCm   PetalWidthCm    : 0.8157894736842105 (Wrong: 7)
# SepalWidthCm    PetalLengthCm   : 0.6842105263157895 (Wrong: 12)
# SepalWidthCm    PetalWidthCm    : 0.7368421052631579 (Wrong: 10)
# PetalLengthCm   PetalWidthCm    : 0.34210526315789475 (Wrong: 25)

# %% [markdown]
# Create confusion matrix to analyze where the misclassifications happen.

# %%
X_test_reduced = X_test[["SepalLengthCm", "PetalWidthCm"]]
y_predicted = mnb.predict(X_test_reduced)
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[15,  0,  0],
#        [ 8,  0,  5],
#        [ 0,  0, 10]], dtype=int64)

# %%
cm_mean = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
classes = unique_labels(y_test, y_predicted)

# %%
fig, ax = plt.subplots()
im = ax.imshow(cm_mean, interpolation='nearest', cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
ax.set(xticks=np.arange(cm_mean.shape[1]),
       yticks=np.arange(cm_mean.shape[0]),
       # ... and label them with the respective list entries
       xticklabels=classes, yticklabels=classes,
       ylabel='True label',
       xlabel='Predicted label')
fig.tight_layout()
plt.show()

# %% [markdown]
# # Use Data for a regression model

# %% [markdown]
# Use the two dimensions "PetalLengthCm" and "PetalWidthCm" that were visually most linear correlated (see above pairplot).

# %%
X_reg = iris[["PetalLengthCm"]]
y_reg = iris["PetalWidthCm"]

reg = LinearRegression()
reg.fit(X_reg, y_reg)
y_reg_predicted = reg.predict(X_reg)
print(f"Intercept: {reg.intercept_}")
print(f"Coefficient: {reg.coef_[0]}")
# Out:
# Intercept: -0.3665140452167275
# Coefficient: 0.4164191322854012

# %% [markdown]
# ## Plot linear regression model

# %%
sns.set()
sns.regplot(x="PetalLengthCm", y="PetalWidthCm", data=iris)
plt.ylim(0,)
plt.xlim(0,7)
# Out:
# (0, 7)

# %% [markdown]
# ## Plot residuals of true values vs. computed graph

# %%
sns.set()
sns.residplot(iris["PetalLengthCm"], iris["PetalWidthCm"])

plt.xlim(0,7)
# Out:
# (0, 7)
